# %%
#1.Prepare Data Set
#2.feast init
#3.Update feature store
#4.Define feature definition
#5.feast apply
#6.Generate Trainning data set
#7.Model Training
#8.Prepare online feature store
import pandas as pd
from feast.types import Int64

# %%
from pathlib import Path
# Definir a raiz do projeto
BASE_DIR = Path("ifood").resolve().parent
print(f'Diretorio encontrado: {BASE_DIR}')
# Out:
# Diretorio encontrado: C:\Users\dmist\Documents\pythonProject\ifood

# %%
df = pd.read_csv('feature_repo/data/restaurant.csv')

# %%
df.head()
# Out:
#                                                   id  \
# 0  d19ff6fca6288939bff073ad0a119d25c0365c407e9e5d...
# 1  631df0985fdbbaf27b9b031a8f381924e3483833385748...
# 2  135c5c4ae4c1ec1fdc23e8c649f313e39be8db913d8bc5...
# 3  d26f84c470451f752bef036c55517b6d9950d41806f10e...
# 4  97b9884600ea7192314580d9115f8882b8634f5aa201ff...
#
#                  created_at  enabled  price_range  average_ticket  \
# 0  2017-01-23T12:52:30.910Z    False            3            60.0
# 1  2017-01-20T13:14:48.286Z     True            3            60.0
# 2  2017-01-23T12:46:33.457Z     True            5           100.0
# 3  2017-01-20T13:15:04.806Z     True            3            80.0
# 4  2017-01-20T13:14:27.701Z     True            3            60.0
#
#    takeout_time  delivery_time  minimum_order_value  merchant_zip_code  \
# 0             0           50.0                 30.0              14025
# 1             0            0.0                 30.0              50180
# 2             0           45.0                 10.0              23090
# 3             0            0.0                 18.9              40255
# 4             0            0.0                 25.0              64600
#
#     merchant_city merchant_state merchant_country
# 0  RIBEIRAO PRETO             SP               BR
# 1       SAO PAULO             SP               BR
# 2  RIO DE JANEIRO             RJ               BR
# 3        SALVADOR             BA               BR
# 4         BARUERI             SP               BR

# %%
# Convertendo a coluna de string para datetime
df['datetime_col'] = pd.to_datetime(df['created_at'], format='%Y-%m-%dT%H:%M:%S.%fZ')

# Convertendo a coluna de string para timestamp
# Dividindo por 10^9 para obter o timestamp em segundos
df['timestamp_col'] = df['datetime_col'].astype('int64') // 10**9

# %%
#Change dataset to Parquet
df.to_parquet(path='feature_repo/data/restaurant.parquet')

# %%
df.head()
# Out:
#                                                   id  \
# 0  d19ff6fca6288939bff073ad0a119d25c0365c407e9e5d...
# 1  631df0985fdbbaf27b9b031a8f381924e3483833385748...
# 2  135c5c4ae4c1ec1fdc23e8c649f313e39be8db913d8bc5...
# 3  d26f84c470451f752bef036c55517b6d9950d41806f10e...
# 4  97b9884600ea7192314580d9115f8882b8634f5aa201ff...
#
#                  created_at  enabled  price_range  average_ticket  \
# 0  2017-01-23T12:52:30.910Z    False            3            60.0
# 1  2017-01-20T13:14:48.286Z     True            3            60.0
# 2  2017-01-23T12:46:33.457Z     True            5           100.0
# 3  2017-01-20T13:15:04.806Z     True            3            80.0
# 4  2017-01-20T13:14:27.701Z     True            3            60.0
#
#    takeout_time  delivery_time  minimum_order_value  merchant_zip_code  \
# 0             0           50.0                 30.0              14025
# 1             0            0.0                 30.0              50180
# 2             0           45.0                 10.0              23090
# 3             0            0.0                 18.9              40255
# 4             0            0.0                 25.0              64600
#
#     merchant_city merchant_state merchant_country            datetime_col  \
# 0  RIBEIRAO PRETO             SP               BR 2017-01-23 12:52:30.910
# 1       SAO PAULO             SP               BR 2017-01-20 13:14:48.286
# 2  RIO DE JANEIRO             RJ               BR 2017-01-23 12:46:33.457
# 3        SALVADOR             BA               BR 2017-01-20 13:15:04.806
# 4         BARUERI             SP               BR 2017-01-20 13:14:27.701
#
#    timestamp_col
# 0     1485175950
# 1     1484918088
# 2     1485175593
# 3     1484918104
# 4     1484918067

# %%
#!feast apply

# %%
#Trainning dataset
from feast import FeatureStore
from feast.infra.offline_stores.file_source import SavedDatasetFileStorage

store = FeatureStore(repo_path=f'{BASE_DIR}/feature_repo')

entity_df = pd.read_parquet(path = 'feature_repo/data/restaurant.parquet')

training_data = store.get_historical_features(
entity_df = entity_df,
    features = [
        "restaurant_fview:enabled",
        "restaurant_fview:price_range",
        "restaurant_fview:average_ticket",
        "restaurant_fview:takeout_time",
        "restaurant_fview:delivery_time",
        "restaurant_fview:minimum_order_value",
        "restaurant_fview:merchant_zip_code",
        "restaurant_fview:merchant_city",
        "restaurant_fview:merchant_state",
        "restaurant_fview:merchant_country"
    ]
)

dataset = store.create_saved_dataset(
from_=training_data,
    name = "restaurant_dataset",
    storage = SavedDatasetFileStorage('feature_repo/data/restaurant_dataset1.parquet')
)
# Out:
# WARNING:root:_list_feature_views will make breaking changes. Please use _list_batch_feature_views instead. _list_feature_views will behave like _list_all_feature_views in the future.
# C:\Users\dmist\Documents\pythonProject\ifoodml\Lib\site-packages\feast\feature_store.py:1155: RuntimeWarning: Saving dataset is an experimental feature. This API is unstable and it could and most probably will be changed in the future. We do not guarantee that future changes will maintain backward compatibility.
#   warnings.warn(
# Using datetime_col as the event timestamp. To specify a column explicitly, please name it event_timestamp.
# ---------------------------------------------------------------------------
# SavedDatasetLocationAlreadyExists         Traceback (most recent call last)
# Cell In[9], line 25
#       7 entity_df = pd.read_parquet(path = 'feature_repo/data/restaurant.parquet')
#       9 training_data = store.get_historical_features(
#      10 entity_df = entity_df,
#      11     features = [
#    (...)
#      22     ]
#      23 )
# ---> 25 dataset = store.create_saved_dataset(
#      26 from_=training_data,
#      27     name = "restaurant_dataset",
#      28     storage = SavedDatasetFileStorage('feature_repo/data/restaurant_dataset1.parquet')
#      29 )
#
# File ~\Documents\pythonProject\ifoodml\Lib\site-packages\feast\feature_store.py:1180, in FeatureStore.create_saved_dataset(self, from_, name, storage, tags, feature_service, allow_overwrite)
#    1177 dataset.min_event_timestamp = from_.metadata.min_event_timestamp
#    1178 dataset.max_event_timestamp = from_.metadata.max_event_timestamp
# -> 1180 from_.persist(storage=storage, allow_overwrite=allow_overwrite)
#    1182 dataset = dataset.with_retrieval_job(
#    1183     self._get_provider().retrieve_saved_dataset(
#    1184         config=self.config, dataset=dataset
#    1185     )
#    1186 )
#    1188 self._registry.apply_saved_dataset(dataset, self.project, commit=True)
#
# File ~\Documents\pythonProject\ifoodml\Lib\site-packages\feast\infra\offline_stores\dask.py:100, in DaskRetrievalJob.persist(self, storage, allow_overwrite, timeout)
#      98 # Check if the specified location already exists.
#      99 if not allow_overwrite and os.path.exists(storage.file_options.uri):
# --> 100     raise SavedDatasetLocationAlreadyExists(location=storage.file_options.uri)
#     102 filesystem, path = FileSource.create_filesystem_and_path(
#     103     storage.file_options.uri,
#     104     storage.file_options.s3_endpoint_override,
#     105 )
#     107 if path.endswith(".parquet"):
#
# SavedDatasetLocationAlreadyExists: Saved dataset location feature_repo/data/restaurant_dataset1.parquet already exists.

# %%
#Training Show
training_data.to_df()
# Out:
#                                                      id  \
# 0     2458597b6740ab52e6834cb92b07072feba38ef303f467...
# 1     645727eda2a5c327f54a7625316f29d52cefd9fb54bd92...
# 2     71319a1000b14c73cb2e364bd9a6f7b807c1cc5f9cef1d...
# 3     c2c2ee7d9350cfcef02c6d333209a1a3ab9c9af932be05...
# 4     1d90c0ccab1b77970dd302dbaf6adefda495bd58ab44bc...
# ...                                                 ...
# 7287  bf9d6811d3bd93f5fb1a9166658660b13c122595ab38a8...
# 7288  fc061ae616f83a94c53ebb548188cd7c09fc6482182a98...
# 7289  cc5514812859f90b6d116417ba3732edc89482b176bcfa...
# 7290  3c3126fab54a9d1a15af43fcda1fde2c49eb18d9ac0423...
# 7291  931da3efd65ffa8ecc6a479ff4f16ee49359e31e89958f...
#
#                     created_at  enabled  price_range  average_ticket  \
# 0     2017-01-20T13:12:43.554Z    False            1            30.0
# 1     2017-01-20T13:12:44.459Z    False            4            80.0
# 2     2017-01-20T13:12:44.503Z    False            5            81.0
# 3     2017-01-20T13:12:45.246Z    False            5            81.0
# 4     2017-01-20T13:12:45.540Z    False            5            81.0
# ...                        ...      ...          ...             ...
# 7287  2017-01-23T12:54:23.246Z    False            4            80.0
# 7288  2017-01-23T12:54:32.760Z    False            1            30.0
# 7289  2017-01-23T12:54:39.558Z    False            1            30.0
# 7290  2017-01-23T12:54:49.183Z    False            1            30.0
# 7291  2017-01-23T12:54:52.155Z    False            1            30.0
#
#       takeout_time  delivery_time  minimum_order_value  merchant_zip_code  \
# 0               30           15.0                  0.0              14510
# 1               30           15.0                 10.0              14260
# 2               30           15.0                  0.0              14140
# 3               30           15.0                 10.0              40030
# 4               30           15.0                 10.0              40760
# ...            ...            ...                  ...                ...
# 7287             0           45.0                 20.0              88015
# 7288             0           30.0                 13.0              22741
# 7289             0           50.0                 10.0              39620
# 7290             0           60.0                  0.0              51020
# 7291             0           30.0                 25.0              35560
#
#       merchant_city  ... enabled__ price_range__ average_ticket__  \
# 0         SAO PAULO  ...     False             1             30.0
# 1         SAO PAULO  ...     False             4             80.0
# 2         SAO PAULO  ...     False             5             81.0
# 3         SAO PAULO  ...     False             5             81.0
# 4         SAO PAULO  ...     False             5             81.0
# ...             ...  ...       ...           ...              ...
# 7287  FLORIANOPOLIS  ...     False             4             80.0
# 7288      SAO PAULO  ...     False             1             30.0
# 7289      SAO PAULO  ...     False             1             30.0
# 7290         RECIFE  ...     False             1             30.0
# 7291      SAO PAULO  ...     False             1             30.0
#
#       takeout_time__  delivery_time__  minimum_order_value__  \
# 0                 30             15.0                    0.0
# 1                 30             15.0                   10.0
# 2                 30             15.0                    0.0
# 3                 30             15.0                   10.0
# 4                 30             15.0                   10.0
# ...              ...              ...                    ...
# 7287               0             45.0                   20.0
# 7288               0             30.0                   13.0
# 7289               0             50.0                   10.0
# 7290               0             60.0                    0.0
# 7291               0             30.0                   25.0
#
#       merchant_zip_code__  merchant_city__  merchant_state__  \
# 0                   14510        SAO PAULO                SP
# 1                   14260        SAO PAULO                SP
# 2                   14140        SAO PAULO                SP
# 3                   40030        SAO PAULO                SP
# 4                   40760        SAO PAULO                SP
# ...                   ...              ...               ...
# 7287                88015    FLORIANOPOLIS                SC
# 7288                22741        SAO PAULO                SP
# 7289                39620        SAO PAULO                SP
# 7290                51020           RECIFE                PE
# 7291                35560        SAO PAULO                SP
#
#       merchant_country__
# 0                     BR
# 1                     BR
# 2                     BR
# 3                     BR
# 4                     BR
# ...                  ...
# 7287                  BR
# 7288                  BR
# 7289                  BR
# 7290                  BR
# 7291                  BR
#
# [7292 rows x 24 columns]

# %%
#Model training
# Importing dependencies
from feast import FeatureStore
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from joblib import dump

# Getting our FeatureStore
store = FeatureStore(repo_path=f'{BASE_DIR}/feature_repo')

# Retrieving the saved dataset and converting it to a DataFrame
training_df = training_data.to_df() #store.get_saved_dataset(name="restaurant_dataset").to_df()
#training_df = training_df.dropna(subset=['price_range'])

# Separating the features and labels
y = training_df['price_range']
X = training_df.drop(
    labels=['price_range', 'datetime_col', "id"], 
    axis=1)

# Apply One-Hot Encoding to all categorical columns
# ValueError: could not convert string to float: '2017-01-20T13:14:42.202Z'
X = pd.get_dummies(X, drop_first=True)

# Splitting the dataset into train and test sets
#X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y)
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

# Remover valores ausentes
X_train = X_train.dropna()
y_train = y_train[X_train.index] 

# Creating and training LogisticRegression
reg = LogisticRegression(max_iter = 200)
reg.fit(X=X_train, y=y_train)

# Saving the model
dump(value=reg, filename="model/model.joblib")
# Out:
# ['model/model.joblib']

# %%
# Ver tipo de cada coluna
#print(X.dtypes)

# Contar vazios
print(X_train.isnull().sum())
# Out:
# enabled                0
# average_ticket         0
# takeout_time           0
# delivery_time          0
# minimum_order_value    0
#                       ..
# merchant_state___RN    0
# merchant_state___RS    0
# merchant_state___SC    0
# merchant_state___SE    0
# merchant_state___SP    0
# Length: 7661, dtype: int64

# %%
#Materialized
#Prepare Online Feature Store
# Importing dependencies
from feast import FeatureStore
from datetime import datetime, timedelta

# Getting our FeatureStore
store = FeatureStore(repo_path=f'{BASE_DIR}/feature_repo')

store.materialize_incremental(end_date = datetime.now())

#store.materialize(start_date=datetime.utcnow() - timedelta(days=530), end_date=datetime.utcnow() - timedelta(days=10))
# Out:
# WARNING:root:_list_feature_views will make breaking changes. Please use _list_batch_feature_views instead. _list_feature_views will behave like _list_all_feature_views in the future.
# Materializing 2 feature views to 2024-10-24 10:43:57-03:00 into the sqlite online store.
#
# restaurant_feature_view from 2024-10-24 09:43:57-03:00 to 2024-10-24 10:43:57-03:00:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 10
#       7 # Getting our FeatureStore
#       8 store = FeatureStore(repo_path=f'{BASE_DIR}/feature_repo')
# ---> 10 store.materialize_incremental(end_date = datetime.now())
#      12 #store.materialize(start_date=datetime.utcnow() - timedelta(days=530), end_date=datetime.utcnow() - timedelta(days=10))
#
# File ~\Documents\pythonProject\ifoodml\Lib\site-packages\feast\feature_store.py:1296, in FeatureStore.materialize_incremental(self, end_date, feature_views)
#    1293 start_date = utils.make_tzaware(start_date)
#    1294 end_date = utils.make_tzaware(end_date)
# -> 1296 provider.materialize_single_feature_view(
#    1297     config=self.config,
#    1298     feature_view=feature_view,
#    1299     start_date=start_date,
#    1300     end_date=end_date,
#    1301     registry=self._registry,
#    1302     project=self.project,
#    1303     tqdm_builder=tqdm_builder,
#    1304 )
#    1306 self._registry.apply_materialization(
#    1307     feature_view,
#    1308     self.project,
#    1309     start_date,
#    1310     end_date,
#    1311 )
#
# File ~\Documents\pythonProject\ifoodml\Lib\site-packages\feast\infra\passthrough_provider.py:332, in PassthroughProvider.materialize_single_feature_view(self, config, feature_view, start_date, end_date, registry, project, tqdm_builder)
#     330 e = jobs[0].error()
#     331 assert e
# --> 332 raise e
#
# File ~\Documents\pythonProject\ifoodml\Lib\site-packages\feast\infra\materialization\local_engine.py:156, in LocalMaterializationEngine._materialize_one(self, registry, feature_view, start_date, end_date, project, tqdm_builder)
#     144 try:
#     145     offline_job = self.offline_store.pull_latest_from_table_or_query(
#     146         config=self.repo_config,
#     147         data_source=feature_view.batch_source,
#    (...)
#     153         end_date=end_date,
#     154     )
# --> 156     table = offline_job.to_arrow()
#     158     if feature_view.batch_source.field_mapping is not None:
#     159         table = _run_pyarrow_field_mapping(
#     160             table, feature_view.batch_source.field_mapping
#     161         )
#
# File ~\Documents\pythonProject\ifoodml\Lib\site-packages\feast\infra\offline_stores\offline_store.py:100, in RetrievalJob.to_arrow(self, validation_reference, timeout)
#      85 def to_arrow(
#      86     self,
#      87     validation_reference: Optional["ValidationReference"] = None,
#      88     timeout: Optional[int] = None,
#      89 ) -> pyarrow.Table:
#      90     """
#      91     Synchronously executes the underlying query and returns the result as an arrow table.
#      92
#    (...)
#      98         timeout (optional): The query timeout if applicable.
#      99     """
# --> 100     features_table = self._to_arrow_internal(timeout=timeout)
#     101     if self.on_demand_feature_views:
#     102         for odfv in self.on_demand_feature_views:
#
# File ~\Documents\pythonProject\ifoodml\Lib\site-packages\feast\infra\offline_stores\dask.py:87, in DaskRetrievalJob._to_arrow_internal(self, timeout)
#      85 def _to_arrow_internal(self, timeout: Optional[int] = None):
#      86     # Only execute the evaluation function to build the final historical retrieval dataframe at the last moment.
# ---> 87     df = self.evaluation_function().compute()
#      88     return pyarrow.Table.from_pandas(df)
#
# File ~\Documents\pythonProject\ifoodml\Lib\site-packages\feast\infra\offline_stores\dask.py:319, in DaskOfflineStore.pull_latest_from_table_or_query.<locals>.evaluate_offline_job()
#     316 def evaluate_offline_job():
#     317     source_df = _read_datasource(data_source)
# --> 319     source_df = _normalize_timestamp(
#     320         source_df, timestamp_field, created_timestamp_column
#     321     )
#     323     source_columns = set(source_df.columns)
#     324     if not set(join_key_columns).issubset(source_columns):
#
# File ~\Documents\pythonProject\ifoodml\Lib\site-packages\feast\infra\offline_stores\dask.py:647, in _normalize_timestamp(df_to_join, timestamp_field, created_timestamp_column)
#     638         df_to_join = df_to_join.drop(columns=dups)
#     640     df_to_join[created_timestamp_column] = df_to_join[
#     641         created_timestamp_column
#     642     ].apply(
#     643         lambda x: x if x.tzinfo is not None else x.replace(tzinfo=pytz.utc),
#     644         meta=(timestamp_field, "datetime64[ns, UTC]"),
#     645     )
# --> 647 return df_to_join.persist()
#
# File ~\Documents\pythonProject\ifoodml\Lib\site-packages\dask_expr\_collection.py:448, in FrameBase.persist(self, fuse, **kwargs)
#     446 def persist(self, fuse=True, **kwargs):
#     447     out = self.optimize(fuse=fuse)
# --> 448     return DaskMethodsMixin.persist(out, **kwargs)
#
# File ~\Documents\pythonProject\ifoodml\Lib\site-packages\dask\base.py:345, in DaskMethodsMixin.persist(self, **kwargs)
#     306 def persist(self, **kwargs):
#     307     """Persist this dask collection into memory
#     308
#     309     This turns a lazy Dask collection into a Dask collection with the same
#    (...)
#     343     dask.persist
#     344     """
# --> 345     (result,) = persist(self, traverse=False, **kwargs)
#     346     return result
#
# File ~\Documents\pythonProject\ifoodml\Lib\site-packages\dask\base.py:997, in persist(traverse, optimize_graph, scheduler, *args, **kwargs)
#     994     postpersists.append((rebuild, a_keys, state))
#     996 with shorten_traceback():
# --> 997     results = schedule(dsk, keys, **kwargs)
#     999 d = dict(zip(keys, results))
#    1000 results2 = [r({k: d[k] for k in ks}, *s) for r, ks, s in postpersists]
#
# File ~\Documents\pythonProject\ifoodml\Lib\site-packages\dask_expr\_expr.py:3778, in Fused._execute_task(graph, name, *deps)
#    3776 for i, dep in enumerate(deps):
#    3777     graph["_" + str(i)] = dep
# -> 3778 return dask.core.get(graph, name)
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# File ~\Documents\pythonProject\ifoodml\Lib\site-packages\feast\infra\offline_stores\dask.py:643, in _normalize_timestamp.<locals>.<lambda>(x)
#     637         df_to_join, dups = _df_column_uniquify(df_to_join)
#     638         df_to_join = df_to_join.drop(columns=dups)
#     640     df_to_join[created_timestamp_column] = df_to_join[
#     641         created_timestamp_column
#     642     ].apply(
# --> 643         lambda x: x if x.tzinfo is not None else x.replace(tzinfo=pytz.utc),
#     644         meta=(timestamp_field, "datetime64[ns, UTC]"),
#     645     )
#     647 return df_to_join.persist()
#
# AttributeError: 'str' object has no attribute 'tzinfo'

# %%
#Get online features
# Importing dependencies
from feast import FeatureStore
import pandas as pd
from joblib import load

# Getting our FeatureStore
store = FeatureStore(repo_path=f'{BASE_DIR}/feature_repo')

# Defining our features names
feast_features = [
        "restaurant_fview:enabled",
        "restaurant_fview:price_range",
        "restaurant_fview:average_ticket",
        "restaurant_fview:takeout_time",
        "restaurant_fview:delivery_time",
        "restaurant_fview:minimum_order_value",
        "restaurant_fview:merchant_zip_code",
        "restaurant_fview:merchant_city",
        "restaurant_fview:merchant_state",
        "restaurant_fview:merchant_country",
    ]

# Getting the latest features
features = store.get_online_features(
    features=feast_features,    
    entity_rows=[{"id": '2458597b6740ab52e6834cb92b07072feba38ef303f4676575ab963513275b3b'}, {"id": 'ac47c7dde8af939606999bd912979082f0c2667a0bc0183712375b5f9ca40fc7'}]
).to_dict()

# Converting the features to a DataFrame
features_df = pd.DataFrame.from_dict(data=features)
# Out:
# WARNING:root:_list_feature_views will make breaking changes. Please use _list_batch_feature_views instead. _list_feature_views will behave like _list_all_feature_views in the future.
# WARNING:root:Cannot use sqlite_vec for vector search

# %%
features_df.head()
# Out:
#                                                   id price_range  \
# 0  2458597b6740ab52e6834cb92b07072feba38ef303f467...        None
# 1  ac47c7dde8af939606999bd912979082f0c2667a0bc018...        None
#
#   merchant_country takeout_time delivery_time minimum_order_value  \
# 0             None         None          None                None
# 1             None         None          None                None
#
#   average_ticket enabled merchant_zip_code merchant_state merchant_city
# 0           None    None              None           None          None
# 1           None    None              None           None          None

# %%
# Loading our model and doing inference
#reg = load("model.joblib")
#predictions = reg.predict(features_df[sorted(features_df.drop("id", axis=1))])
#print(predictions)

def load_model(model_path):
    """Carrega o modelo treinado."""
    try:
        model = load(model_path)
        print(f"Modelo carregado com sucesso de {model_path}")
        return model
    except Exception as e:
        print(f"Erro ao carregar o modelo: {e}")
        raise
    
def preprocess_features(features_df):
    """Pré-processa o DataFrame de features para garantir que as colunas estejam corretas."""
    try:
        # Remover a coluna 'id' e ordenar as colunas para garantir compatibilidade com o modelo
        preprocessed_features = features_df.drop("id", axis=1)
        preprocessed_features = preprocessed_features[sorted(preprocessed_features.columns)]
        
        # Verificar se há valores nulos
        if preprocessed_features.isnull().sum().sum() > 0:
            raise ValueError("Há valores nulos nas features fornecidas.")
        
        return preprocessed_features
    except Exception as e:
        print(f"Erro durante o pré-processamento das features: {e}")
        raise
    
def make_predictions(model, features_df):
    """Realiza previsões usando o modelo treinado e as features fornecidas."""
    try:
        predictions = model.predict(features_df)
        return predictions
    except Exception as e:
        print(f"Erro ao fazer previsões: {e}")
        raise

# Caminho do modelo treinado
model_path = "model/model.joblib"

# Carregar o modelo treinado
reg = load_model(model_path)

# Pré-processar as features
features_df_preprocessed = preprocess_features(features_df)

# Realizar as previsões
predictions = make_predictions(reg, features_df_preprocessed)

# Exibir as previsões
print(predictions)
# Out:
# Modelo carregado com sucesso de model/model.joblib
# Erro durante o pré-processamento das features: Há valores nulos nas features fornecidas.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 48
#      45 reg = load_model(model_path)
#      47 # Pré-processar as features
# ---> 48 features_df_preprocessed = preprocess_features(features_df)
#      50 # Realizar as previsões
#      51 predictions = make_predictions(reg, features_df_preprocessed)
#
# Cell In[20], line 25, in preprocess_features(features_df)
#      23     # Verificar se há valores nulos
#      24     if preprocessed_features.isnull().sum().sum() > 0:
# ---> 25         raise ValueError("Há valores nulos nas features fornecidas.")
#      27     return preprocessed_features
#      28 except Exception as e:
#
# ValueError: Há valores nulos nas features fornecidas.

# %%
#API FasAPI
#Definir Caminho para Chamar API
# Definir a raiz do projeto da API
BASE_DIR_API = f'{BASE_DIR}' 

print(f'Diretorio api: {BASE_DIR_API}')
# Out:
# Diretorio api: C:\Users\dmist\Documents\pythonProject\ifood

# %%
#Iniciar a API via linha de comando (cmd/terminal)
#acessar o diretorio api onde está o arquivo main.py
#executar o comando abaixo. Trocar a porta para 9000 em caso de conflito
# !uvicorn main:app --reload --port 8080
# Out:
# INFO:     Will watch for changes in these directories: ['C:\\Users\\dmist\\Documents\\pythonProject\\ifood']
# INFO:     Uvicorn running on http://127.0.0.1:8080 (Press CTRL+C to quit)
# INFO:     Started reloader process [21984] using WatchFiles
# INFO:     Stopping reloader process [21984]

# %%
#Após executar API, acessar a documentação em: http://localhost:8080/docs
